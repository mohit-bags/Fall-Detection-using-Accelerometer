# %%
# importing libraries
# %matplotlib inline
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("testing_0_occurence_Log 2022-01-20 19_21_12.txt.csv",header=None)

# %%
df.columns=['X','Y','Z','Magnitude']

# %%
df
# Out:
#        X   Y     Z    Magnitude
# 0     16   0  1000  1000.127992
# 1     24 -32   984   984.812672
# 2     24 -24   992   992.580475
# 3     40 -40  1016  1017.573585
# 4     32 -48  1000  1001.662618
# ...   ..  ..   ...          ...
# 3245  16  72  1000  1002.716311
# 3246  24  64   984   986.371127
# 3247   8  72  1000  1002.620566
# 3248  24  80  1000  1003.481938
# 3249  16  72  1000  1002.716311
#
# [3250 rows x 4 columns]

# %%
sns.lineplot(y = 'X', x = df.index, data = df)
sns.lineplot(y = 'Y', x =  df.index, data = df)
sns.lineplot(y = 'Z', x =  df.index, data = df)
sns.lineplot(y = 'Magnitude', x =  df.index, data = df)

plt.legend(['X', 'Y', 'Z','Magnitude'])
plt.ylabel("magnitude")
plt.title("Plot", fontsize = 15)
plt.rcParams["figure.figsize"] = (20,7)
plt.show()

# %%
def extract_mean_max_min(data,start_time,win_size=50): #25Hz
